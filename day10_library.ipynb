# %% [markdown]
# - Built in module
# - Custom module

# %%
import day

# %%
import math

# %% [markdown]
# - Basic maths --sum, sub , multi, power(), square root, -- basic.py
# - log(10), logr --- log.py
# - Trignometry --tri.py
# - constant-- pi  constant.py

# %%
import random

# %%
import time

# %%
pip uninstall Math
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement Math (from versions: none)
# ERROR: No matching distribution found for Math
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip list
# Out:
# Package                      VersionNote: you may need to restart the kernel to use updated packages.
#
# ---------------------------- --------------
# absl-py                      2.1.0
# aiohttp                      3.9.1
# aiosignal                    1.3.1
# altair                       5.2.0
# annotated-types              0.6.0
# ansi2html                    1.9.1
# anyio                        4.2.0
# appdirs                      1.4.4
# arrow                        1.3.0
# astor                        0.8.1
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        23.2.0
# backcall                     0.2.0
# backoff                      2.2.1
# beautifulsoup4               4.12.2
# bleach                       6.1.0
# blinker                      1.7.0
# boto                         2.49.0
# boto3                        1.34.37
# botocore                     1.34.37
# branca                       0.7.0
# ...

# %%
import zipp

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
help(time)
# Out:
# Help on built-in module time:
#
# NAME
#     time - This module provides various functions to manipulate time values.
#
# DESCRIPTION
#     There are two standard representations of time.  One is the number
#     of seconds since the Epoch, in UTC (a.k.a. GMT).  It may be an integer
#     or a floating point number (to represent fractions of seconds).
#     The Epoch is system-defined; on Unix, it is generally January 1st, 1970.
#     The actual value can be retrieved by calling gmtime(0).
#
#     The other representation is a tuple of 9 integers giving local time.
#     The tuple items are:
#       year (including century, e.g. 1998)
#       month (1-12)
#       day (1-31)
#       hours (0-23)
#       minutes (0-59)
#       seconds (0-59)
#       weekday (0-6, Monday is 0)
#       Julian day (day in the year, 1-366)
#       DST (Daylight Savings Time) flag (-1, 0 or 1)
#     If the DST flag is 0, the time is given in the regular time zone;
# ...

# %%
import math as m

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
m.sqrt(16)
# Out:
# 4.0

# %%
m.pow(5,3)
# Out:
# 125.0

# %%
m.factorial(5)
# Out:
# 120

# %%
m.pi
# Out:
# 3.141592653589793

# %%
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
random.random() # 0-1
# Out:
# 0.48275039733213176

# %%
random.randint(50,100)
# Out:
# 99

# %%
shopping_list=["Apple","Banana","Laptop","Mouse"]

# %%
random.choice(shopping_list)
# Out:
# 'Laptop'

# %%
random.shuffle(shopping_list)

# %%
shopping_list
# Out:
# ['Laptop', 'Banana', 'Apple', 'Mouse']

# %%
l1=[95,65,85,95,6,3,963,9,39,31,9,3,6]

# %%
samp=random.sample(l1,3)

# %%
print(samp)
# Out:
# [95, 6, 85]

# %%
random.uniform(3.5,6.5)
# Out:
# 5.038467597897805

# %%
random.seed(10)
random.random()
# Out:
# 0.5714025946899135

# %%
random.seed(None)
random.random()
# Out:
# 0.08165876443990538

# %%
help(time)
# Out:
# Help on built-in module time:
#
# NAME
#     time - This module provides various functions to manipulate time values.
#
# DESCRIPTION
#     There are two standard representations of time.  One is the number
#     of seconds since the Epoch, in UTC (a.k.a. GMT).  It may be an integer
#     or a floating point number (to represent fractions of seconds).
#     The Epoch is system-defined; on Unix, it is generally January 1st, 1970.
#     The actual value can be retrieved by calling gmtime(0).
#
#     The other representation is a tuple of 9 integers giving local time.
#     The tuple items are:
#       year (including century, e.g. 1998)
#       month (1-12)
#       day (1-31)
#       hours (0-23)
#       minutes (0-59)
#       seconds (0-59)
#       weekday (0-6, Monday is 0)
#       Julian day (day in the year, 1-366)
#       DST (Daylight Savings Time) flag (-1, 0 or 1)
#     If the DST flag is 0, the time is given in the regular time zone;
# ...

# %%
time.time()
# Out:
# 1725121365.9111738

# %%
print("Hello ")
time.sleep(2)
print("Learners")
# Out:
# Hello
# Learners

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2024, tm_mon=8, tm_mday=31, tm_hour=21, tm_min=54, tm_sec=33, tm_wday=5, tm_yday=244, tm_isdst=0)

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2024, tm_mon=8, tm_mday=31, tm_hour=16, tm_min=28, tm_sec=15, tm_wday=5, tm_yday=244, tm_isdst=0)

# %%
formatted=time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted)
# Out:
# 2024-08-31 21:58:57
